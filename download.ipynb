# %%
from pytubefix import YouTube
from pytubefix import Channel
from pytubefix import Playlist
# from pytubefix.cli import on_progress

# %%
c = Channel("https://www.youtube.com/@lastdays247")
c.channel_name
# Out:
# 'Last Days'

# %%
url = "https://youtu.be/tMKXbLBgkEc"

yt = YouTube(url)
yt.title
# Out:
# 'CAR vs. WORLD’S STRONGEST TRAMPOLINE- 150ft (45m) drop'

# %%
yt.captions
# Out:
# {'ar': <Caption lang="Arabic" code="ar">, 'fr': <Caption lang="French" code="fr">, 'hi': <Caption lang="Hindi" code="hi">, 'id': <Caption lang="Indonesian" code="id">, 'ko': <Caption lang="Korean" code="ko">, 'pt-BR': <Caption lang="Portuguese (Brazil)" code="pt-BR">, 'ru': <Caption lang="Russian" code="ru">, 'es-419': <Caption lang="Spanish (Latin America)" code="es-419">, 'th': <Caption lang="Thai" code="th">, 'tr': <Caption lang="Turkish" code="tr">, 'vi': <Caption lang="Vietnamese" code="vi">}

# %%
yt.channel_id
# Out:
# 'UCBqj7_4xib9pKATW4394PmQ'

# %%
captions = yt.captions.get('a.en', None)
captions.generate_srt_captions()
# Out:
# "1\n00:00:00,120 --> 00:00:06,680\nhey good morning family praise the lord\n\n2\n00:00:02,919 --> 00:00:08,960\nit's day 58 y'all I know we missed\n\n3\n00:00:06,680 --> 00:00:11,599\nyesterday but we had some things come up\n\n4\n00:00:08,960 --> 00:00:12,920\nand um and so we're here today but I\n\n5\n00:00:11,599 --> 00:00:17,000\njust want to tell you all thank you for\n\n6\n00:00:12,920 --> 00:00:20,519\njoining us um Diana has a word from the\n\n7\n00:00:17,000 --> 00:00:23,840\nLord that I know is the the Lord and uh\n\n8\n00:00:20,519 --> 00:00:25,840\nit's correction but it's also beautiful\n\n9\n00:00:23,840 --> 00:00:27,800\nit I love correction from the Lord\n\n10\n00:00:25,840 --> 00:00:30,240\nbecause that's what makes us grow and\n\n11\n00:00:27,800 --> 00:00:33,879\nthat's how we go from glory to glory\n\n12\n00:00:30,240 --> 00:00:36,840\nit's it's the it's the Refiner's Fire\n\n13\n00:00:33,879 --> 00:00:39,840\nthat makes us stronger and and and\n\n14\n00:00:36,840
# ...

# %%
captions.generate_srt_captions
# Out:
# <bound method Caption.generate_srt_captions of <Caption lang="English (auto-generated)" code="a.en">>

# %%
print(yt.captions)
caption = yt.captions['a.en']
caption.save_captions('c.txt')
